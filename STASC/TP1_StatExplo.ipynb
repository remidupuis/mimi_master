# %% [markdown]
# # Descriptive statistics, statistical models, data visualization

# %% [markdown]
# In this lab, we  study the [United States Renewable Energy Technical Potential dataset](https://data.world/doe/united-states-renewable-energy).
#
# Create an account on data.world to download the [usretechnicalpotential.csv
# ](https://data.world/doe/united-states-renewable-energy/workspace/file?filename=usretechnicalpotential.csv) file.
#
# This dataset provides the technical potential of renewable energie for the states of USA.
#
# The technical potential of a renewable energy represents the achievable energy generation of a particular technology given system performance, topographic limitations, environmental, and land-use constraints.
#
# List of renewable energies considered in the dataset:
# - Urban utility-scale photovoltaics
# - Rural utility-scale photovoltaics
# - Rooftop photovoltaics
# - Concentrating solar power
# - Onshore wind power
# - Offshore wind power
# - Biopower
# - Hydrothermal power systems
# - Enhanced geothermal
# - Hydropower
#
# Precise definitions of the variables (columns) in the dataset are given in the [technical report](https://data.world/doe/united-states-renewable-energy/workspace/file?filename=usretechpotential.pdf). Take the time to read these definitions to understand the exact meaning of the available variables.

# %% [markdown]
# We use several Python modules dedicated to statistical data processing.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats 
import numpy
import seaborn as sns

# %% [markdown]
# Python comes with a package for handling data as a table : the [Pandas](http://pandas.pydata.org/) package provides a container for tables, called **dataframe**.
#
# We recommend that you have a look at the ["10 minutes to pandas" doc](https://pandas.pydata.org/docs/user_guide/10min.html#min).
#
# A dataframe is a two-dimensional table, in which each column contains measurements on one variable, and each row contains one individual.
#
# The main features of Pandas and its dataframe are:
# - reading data from csv and Excel files;
# - giving names to variables;
# - storing in a clever manner a large amound of data;
# - providing methods for descriptive statistics.

# %% [markdown]
# ## Creating and reading a dataframe <a id="part2sec1"></a>

# %% [markdown]
# A dataframe may be either read from a file or created from raw data.

# %%
usretechnical = pd.read_csv('https://query.data.world/s/mpz73nfn7kkhva3gel7j2rhedp25hw?dws=00000', index_col = 0)
usretechnical
# Out:
#                       urbanUtilityScalePV_GWh  urbanUtilityScalePV_GW  \
# Alabama                                 35850                      20
# Alaska                                    166                       0
# Arizona                                121305                      52
# Arkansas                                28960                      15
# California                             246008                     111
# Colorado                                43470                      19
# Connecticut                              7716                       4
# Delaware                                14856                       9
# District of Columbia                        8                       0
# Florida                                 72787                      39
# Georgia                                 43166                      24
# Hawaii                                   3725                       1
# Idaho                                   23194                      12
# Illinois                               103551                      63
# Indiana                                 98815                      61
# Iowa                                    27091                      15
# Kansas                                  31705                      15
# Kentucky                                26514                      16
# Louisiana                               55669                      32
# Maine                                    3216                       1
# Maryland                                28551                      18
# Massachusetts                           17469                      10
# Michigan                                50845                      33
# Minnesota                               33370                      20
# Mississippi                             26366                      15
# Missouri                                30549                      18
# Montana                                 11370                       6
# Nebraska                                12954                       6
# Nevada                                  24893                      10
# New Hampshire                            3790                       2
# New Jersey                              44307                      25
# New Mexico                              71356                      30
# New York                                52803                      32
# North Carolina                          68346                      37
# North Dakota                             4871                       2
# Ohio                                    86495                      57
# Oklahoma                                50040                      25
# Oregon                                  25783                      12
# Pennsylvania                            56161                      36
# Rhode Island                             1787                       1
# South Carolina                          33834                      19
# South Dakota                             4573                       2
# Tennessee                               50243                      28
# Texas                                  294684                     154
# Utah                                    30492                      14
# Vermont                                  1632                       1
# Virginia                                27451                      15
# Washington                              33690                      19
# West Virginia                            3023                       2
# Wisconsin                               54938                      34
# Wyoming                                  7232                       3
#
#                       urbanUtilityScalePV_km2  ruralUtilityScalePV_GWh  \
# Alabama                                   426                  3706838
# Alaska                                      2                  8282976
# Arizona                                  1096                 11867693
# Arkansas                                  332                  4986388
# California                               2320                  8855917
# Colorado                                  399                 10238083
# Connecticut                               100                    19627
# Delaware                                  189                   272332
# District of Columbia                        0                        0
# Florida                                   830                  5137346
# Georgia                                   505                  5492183
# Hawaii                                     34                    38032
# Idaho                                     251                  3936847
# Illinois                                 1324                  8090985
# Indiana                                  1274                  4876185
# Iowa                                      324                  6994159
# Kansas                                    317                 14500149
# Kentucky                                  338                  1823976
# Louisiana                                 674                  4114605
# Maine                                      40                  1100327
# Maryland                                  378                   585949
# Massachusetts                             228                    82204
# Michigan                                  699                  5215639
# Minnesota                                 419                 10792814
# Mississippi                               317                  4981252
# Missouri                                  376                  5335268
# Montana                                   127                  8187341
# Nebraska                                  141                  9266756
# Nevada                                    224                  8614454
# New Hampshire                              48                    57363
# New Jersey                                527                   439773
# New Mexico                                645                 16318543
# New York                                  682                  1492566
# North Carolina                            789                  4232789
# North Dakota                               57                  9734447
# Ohio                                     1190                  3626181
# Oklahoma                                  533                  9341920
# Oregon                                    270                  3740478
# Pennsylvania                              754                   553356
# Rhode Island                               24                    13636
# South Carolina                            397                  2754973
# South Dakota                               50                 10008873
# Tennessee                                 595                  2225989
# Texas                                    3213                 38993581
# Utah                                      292                  5184878
# Vermont                                    22                    54727
# Virginia                                  326                  1882467
# Washington                                402                  1738150
# West Virginia                              41                    52693
# Wisconsin                                 727                  5042258
# Wyoming                                    75                  5727224
#
#                       ruralUtilityScalePV_GW  ruralUtilityScalePV_km2  \
# Alabama                                 2114                    44058
# Alaska                                  9005                   187608
# Arizona                                 5147                   107230
# Arkansas                                2747                    57239
# California                              4010                    83549
# Colorado                                4514                    94046
# Connecticut                               12                      256
# Delaware                                 167                     3482
# District of Columbia                       0                        0
# Florida                                 2812                    58596
# Georgia                                 3088                    64343
# Hawaii                                    20                      430
# Idaho                                   2045                    42612
# Illinois                                4969                   103524
# Indiana                                 3018                    62890
# Iowa                                    4020                    83762
# Kansas                                  6959                   144995
# Kentucky                                1119                    23319
# Louisiana                               2394                    49876
# Maine                                    658                    13722
# Maryland                                 373                     7772
# Massachusetts                             51                     1074
# Michigan                                3443                    71740
# Minnesota                               6510                   135627
# Mississippi                             2879                    59996
# Missouri                                3156                    65766
# Montana                                 4402                    91724
# Nebraska                                4869                   101456
# Nevada                                  3732                    77751
# New Hampshire                             35                      741
# New Jersey                               251                     5231
# New Mexico                              7087                   147652
# New York                                 926                    19294
# North Carolina                          2346                    48892
# North Dakota                            5482                   114227
# Ohio                                    2395                    49908
# Oklahoma                                4782                    99640
# Oregon                                  1884                    39266
# Pennsylvania                             356                     7429
# Rhode Island                               8                      184
# South Carolina                          1555                    32398
# South Dakota                            5344                   111350
# Tennessee                               1266                    26395
# Texas                                  20411                   425230
# Utah                                    2390                    49797
# Vermont                                   35                      739
# Virginia                                1074                    22377
# Washington                               996                    20758
# West Virginia                             35                      729
# Wisconsin                               3205                    66788
# Wyoming                                 2854                    59463
#
#                       rooftopPV_GWh  rooftopPV_GW   CSP_GWh  CSP_GW  ...  \
# Alabama                     15475.0            12         0       0  ...
# Alaska                          NaN             1         0       0  ...
# Arizona                     22736.0            14  12544333    3527  ...
# Arkansas                     8484.0             6         0       0  ...
# California                 106411.0            75   8490916    2725  ...
# Colorado                    16162.0            11   9154524    3097  ...
# Connecticut                  6616.0             5         0       0  ...
# Delaware                     2185.0             1         0       0  ...
# District of Columbia         2490.0             2         0       0  ...
# Florida                     63986.0            49       358       0  ...
# Georgia                     31116.0            24         0       0  ...
# Hawaii                          NaN             2     15369       5  ...
# Idaho                        4051.0             3   3502877    1267  ...
# Illinois                    30086.0            26         0       0  ...
# Indiana                     17151.0            14         0       0  ...
# Iowa                         8646.0             7         0       0  ...
# Kansas                       8962.0             6   7974255    2884  ...
# Kentucky                    12312.0            10         0       0  ...
# Louisiana                   14368.0            11         0       0  ...
# Maine                        2443.0             2         0       0  ...
# Maryland                    14849.0            12         0       0  ...
# Massachusetts               11722.0            10         0       0  ...
# Michigan                    23527.0            21         0       0  ...
# Minnesota                   14321.0            12         0       0  ...
# Mississippi                  8614.0             6         0       0  ...
# Missouri                    16159.0            13         0       0  ...
# Montana                      2194.0             1   1540287     557  ...
# Nebraska                     5336.0             4   4846929    1753  ...
# Nevada                      10767.0             7   8295752    2557  ...
# New Hampshire                2298.0             2         0       0  ...
# New Jersey                  15767.0            13         0       0  ...
# New Mexico                   6513.0             4  16812349    4860  ...
# New York                    28779.0            25         0       0  ...
# North Carolina              28419.0            23         0       0  ...
# North Dakota                 1916.0             1     36049      13  ...
# Ohio                        30064.0            27         0       0  ...
# Oklahoma                    12442.0             9   5068036    1812  ...
# Oregon                       8322.0             7   2812126    1017  ...
# Pennsylvania                22215.0            19         0       0  ...
# Rhode Island                 1710.0             1         0       0  ...
# South Carolina              14412.0            11         0       0  ...
# South Dakota                 2082.0             1   1629659     589  ...
# Tennessee                   19685.0            16         0       0  ...
# Texas                       78716.0            60  22786749    7743  ...
# Utah                         7513.0             5   5067546    1638  ...
# Vermont                      1115.0             1         0       0  ...
# Virginia                    22266.0            18         0       0  ...
# Washington                  13599.0            13    161713      58  ...
# West Virginia                4220.0             3         0       0  ...
# Wisconsin                   13939.0            12         0       0  ...
# Wyoming                      1550.0             1   5406407    1955  ...
#
#                       biopowerGaseous_GWh  biopowerGaseous_GW  \
# Alabama                              1533                   0
# Alaska                                 61                   0
# Arizona                               837                   0
# Arkansas                             1063                   0
# California                          15510                   1
# Colorado                             1224                   0
# Connecticut                           414                   0
# Delaware                              385                   0
# District of Columbia                    4                   0
# Florida                              3693                   0
# Georgia                              2220                   0
# Hawaii                                200                   0
# Idaho                                 182                   0
# Illinois                             4222                   0
# Indiana                              2978                   0
# Iowa                                 1425                   0
# Kansas                                753                   0
# Kentucky                             1273                   0
# Louisiana                             857                   0
# Maine                                 124                   0
# Maryland                             1226                   0
# Massachusetts                        1103                   0
# Michigan                             2539                   0
# Minnesota                            1029                   0
# Mississippi                          1076                   0
# Missouri                             2147                   0
# Montana                               147                   0
# Nebraska                              750                   0
# Nevada                                325                   0
# New Hampshire                         389                   0
# New Jersey                           2310                   0
# New Mexico                            353                   0
# New York                             2950                   0
# North Carolina                       3780                   0
# North Dakota                           30                   0
# Ohio                                 3363                   0
# Oklahoma                              965                   0
# Oregon                                890                   0
# Pennsylvania                         7132                   0
# Rhode Island                          474                   0
# South Carolina                       1430                   0
# South Dakota                          235                   0
# Tennessee                            1984                   0
# Texas                                5898                   0
# Utah                                  427                   0
# Vermont                               203                   0
# Virginia                             2498                   0
# Washington                           1514                   0
# West Virginia                         281                   0
# Wisconsin                            2072                   0
# Wyoming                                50                   0
#
#                       biopowerGaseous_Tonnes-CH4  geothermalHydrothermal_GWh  \
# Alabama                                   326186                           0
# Alaska                                     13156                       15437
# Arizona                                   178188                        8329
# Arkansas                                  226178                           0
# California                               3300211                      130921
# Colorado                                  260470                        8953
# Connecticut                                88227                           0
# Delaware                                   82013                           0
# District of Columbia                         977                           0
# Florida                                   785787                           0
# Georgia                                   472546                           0
# Hawaii                                     42602                       20632
# Idaho                                      38830                       17205
# Illinois                                  898345                           0
# Indiana                                   633660                           0
# Iowa                                      303277                           0
# Kansas                                    160219                           0
# Kentucky                                  271052                           0
# Louisiana                                 182404                           0
# Maine                                      26542                           0
# Maryland                                  260965                           0
# Massachusetts                             234811                           0
# Michigan                                  540282                           0
# Minnesota                                 219074                           0
# Mississippi                               229076                           0
# Missouri                                  456990                           0
# Montana                                    31324                        6547
# Nebraska                                  159729                           0
# Nevada                                     69248                       45320
# New Hampshire                              82889                           0
# New Jersey                                491691                           0
# New Mexico                                 75228                       12933
# New York                                  627734                           0
# North Carolina                            804301                           0
# North Dakota                                6383                           0
# Ohio                                      715603                           0
# Oklahoma                                  205359                           0
# Oregon                                    189571                       18199
# Pennsylvania                             1517540                           0
# Rhode Island                              100888                           0
# South Carolina                            304312                           0
# South Dakota                               50072                           0
# Tennessee                                 422220                           0
# Texas                                    1254999                           0
# Utah                                       91018                       12981
# Vermont                                    43248                           0
# Virginia                                  531592                           0
# Washington                                322155                        2546
# West Virginia                              59811                           0
# Wisconsin                                 441053                           0
# Wyoming                                    10670                        1373
#
#                       geothermalHydrothermal_GW  EGSGeothermal_GWh  \
# Alabama                                       0           535489.0
# Alaska                                        1                NaN
# Arizona                                       1          1239147.0
# Arkansas                                      0           628621.0
# California                                   16          1344179.0
# Colorado                                      1          1251657.0
# Connecticut                                   0            56078.0
# Delaware                                      0            22813.0
# District of Columbia                          0              697.0
# Florida                                       0           374161.0
# Georgia                                       0           353206.0
# Hawaii                                        2                NaN
# Idaho                                         2           993257.0
# Illinois                                      0           676055.0
# Indiana                                       0           434258.0
# Iowa                                          0           606390.0
# Kansas                                        0           989675.0
# Kentucky                                      0           484658.0
# Louisiana                                     0           484271.0
# Maine                                         0           377075.0
# Maryland                                      0            86649.0
# Massachusetts                                 0            92227.0
# Michigan                                      0           457850.0
# Minnesota                                     0           369784.0
# Mississippi                                   0           559056.0
# Missouri                                      0           835444.0
# Montana                                       0          1647303.0
# Nebraska                                      0           927996.0
# Nevada                                        5          1262174.0
# New Hampshire                                 0           104314.0
# New Jersey                                    0            35230.0
# New Mexico                                    1          1417978.0
# New York                                      0           375400.0
# North Carolina                                0           420741.0
# North Dakota                                  0           820226.0
# Ohio                                          0           495921.0
# Oklahoma                                      0           779667.0
# Oregon                                        2           914105.0
# Pennsylvania                                  0           327340.0
# Rhode Island                                  0            11491.0
# South Carolina                                0           364104.0
# South Dakota                                  0           921972.0
# Tennessee                                     0           428380.0
# Texas                                         0          3030250.0
# Utah                                          1           939380.0
# Vermont                                       0            35616.0
# Virginia                                      0           290736.0
# Washington                                    0           563023.0
# West Virginia                                 0           261376.0
# Wisconsin                                     0           647173.0
# Wyoming                                       0          1070078.0
#
#                       EGSGeothermal_GW  hydropower_GWh  hydropower_GW  \
# Alabama                           67.0            4102              0
# Alaska                             NaN           23675              5
# Arizona                          157.0            1303              0
# Arkansas                          79.0            6093              1
# California                       170.0           30023              6
# Colorado                         158.0            7789              1
# Connecticut                        7.0             922              0
# Delaware                           2.0              30              0
# District of Columbia               0.0               0              0
# Florida                           47.0             682              0
# Georgia                           44.0            1988              0
# Hawaii                             NaN            2602              0
# Idaho                            125.0           18757              4
# Illinois                          85.0            4882              1
# Indiana                           55.0            2394              0
# Iowa                              76.0            2818              0
# Kansas                           125.0            2507              0
# Kentucky                          61.0            4255              0
# Louisiana                         61.0            2423              0
# Maine                             47.0            3916              0
# Maryland                          10.0             814              0
# Massachusetts                     11.0            1196              0
# Michigan                          58.0            1180              0
# Minnesota                         46.0            1254              0
# Mississippi                       70.0            2211              0
# Missouri                         105.0            7198              1
# Montana                          208.0           14546              3
# Nebraska                         117.0            3142              0
# Nevada                           160.0             845              0
# New Hampshire                     13.0            1740              0
# New Jersey                         4.0             549              0
# New Mexico                       179.0            1362              0
# New York                          47.0            6711              1
# North Carolina                    53.0            3036              0
# North Dakota                     104.0             347              0
# Ohio                              62.0            3045              0
# Oklahoma                          98.0            3015              0
# Oregon                           115.0           18184              4
# Pennsylvania                      41.0            8368              1
# Rhode Island                       1.0              59              0
# South Carolina                    46.0            1888              0
# South Dakota                     116.0            1047              0
# Tennessee                         54.0            5744              1
# Texas                            384.0            3006              0
# Utah                             119.0            3528              0
# Vermont                            4.0            1710              0
# Virginia                          36.0            3656              0
# Washington                        71.0           27248              6
# West Virginia                     33.0            4408              1
# Wisconsin                         82.0            2286              1
# Wyoming                          135.0            4445              1
#
#                       hydropower_countOfSites
# Alabama                                  2435
# Alaska                                   3053
# Arizona                                  1958
# Arkansas                                 3268
# California                               9692
# Colorado                                 5060
# Connecticut                               659
# Delaware                                   25
# District of Columbia                        2
# Florida                                   493
# Georgia                                  2100
# Hawaii                                    437
# Idaho                                    6706
# Illinois                                 1330
# Indiana                                  1142
# Iowa                                     2398
# Kansas                                   3201
# Kentucky                                 1394
# Louisiana                                 934
# Maine                                    1373
# Maryland                                  491
# Massachusetts                             560
# Michigan                                 1942
# Minnesota                                1391
# Mississippi                              1536
# Missouri                                 5089
# Montana                                  6859
# Nebraska                                 2880
# Nevada                                   1489
# New Hampshire                             810
# New Jersey                                402
# New Mexico                               1810
# New York                                 4839
# North Carolina                           2131
# North Dakota                              572
# Ohio                                     1791
# Oklahoma                                 2824
# Oregon                                   7993
# Pennsylvania                             4466
# Rhode Island                               86
# South Carolina                            889
# South Dakota                             1712
# Tennessee                                2610
# Texas                                    4366
# Utah                                     3394
# Vermont                                  1207
# Virginia                                 2601
# Washington                               7310
# West Virginia                            1711
# Wisconsin                                1863
# Wyoming                                  2842
#
# [51 rows x 30 columns]

# %% [markdown]
# Since it is unrealistic to view a table in whole, Pandas provides different methods to give a sneak look at the aforesaid table.

# %%
usretechnical.index  # Index of the table
# Out:
# Index(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado',
#        'Connecticut', 'Delaware', 'District of Columbia', 'Florida', 'Georgia',
#        'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky',
#        'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan',
#        'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada',
#        'New Hampshire', 'New Jersey', 'New Mexico', 'New York',
#        'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota',
#        'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'],
#       dtype='object')

# %%
usretechnical.columns  # Columns of the table
# Out:
# Index(['urbanUtilityScalePV_GWh', 'urbanUtilityScalePV_GW',
#        'urbanUtilityScalePV_km2', 'ruralUtilityScalePV_GWh',
#        'ruralUtilityScalePV_GW', 'ruralUtilityScalePV_km2', 'rooftopPV_GWh',
#        'rooftopPV_GW', 'CSP_GWh', 'CSP_GW', 'CSP_km2', 'onshoreWind_GWh',
#        'onshoreWind_GW', 'onshoreWind_km2', 'offshoreWind_GWh',
#        'offshoreWind_GW', 'offshoreWind_km2', 'biopowerSolid_GWh',
#        'biopowerSolid_GW', 'biopowerSolid_BDT', 'biopowerGaseous_GWh',
#        'biopowerGaseous_GW', 'biopowerGaseous_Tonnes-CH4',
#        'geothermalHydrothermal_GWh', 'geothermalHydrothermal_GW',
#        'EGSGeothermal_GWh', 'EGSGeothermal_GW', 'hydropower_GWh',
#        'hydropower_GW', 'hydropower_countOfSites'],
#       dtype='object')

# %%
usretechnical.head(n=3)
# Out:
#          urbanUtilityScalePV_GWh  urbanUtilityScalePV_GW  \
# Alabama                    35850                      20
# Alaska                       166                       0
# Arizona                   121305                      52
#
#          urbanUtilityScalePV_km2  ruralUtilityScalePV_GWh  \
# Alabama                      426                  3706838
# Alaska                         2                  8282976
# Arizona                     1096                 11867693
#
#          ruralUtilityScalePV_GW  ruralUtilityScalePV_km2  rooftopPV_GWh  \
# Alabama                    2114                    44058        15475.0
# Alaska                     9005                   187608            NaN
# Arizona                    5147                   107230        22736.0
#
#          rooftopPV_GW   CSP_GWh  CSP_GW  ...  biopowerGaseous_GWh  \
# Alabama            12         0       0  ...                 1533
# Alaska              1         0       0  ...                   61
# Arizona            14  12544333    3527  ...                  837
#
#          biopowerGaseous_GW  biopowerGaseous_Tonnes-CH4  \
# Alabama                   0                      326186
# Alaska                    0                       13156
# Arizona                   0                      178188
#
#          geothermalHydrothermal_GWh  geothermalHydrothermal_GW  \
# Alabama                           0                          0
# Alaska                        15437                          1
# Arizona                        8329                          1
#
#          EGSGeothermal_GWh  EGSGeothermal_GW  hydropower_GWh  hydropower_GW  \
# Alabama           535489.0              67.0            4102              0
# Alaska                 NaN               NaN           23675              5
# Arizona          1239147.0             157.0            1303              0
#
#          hydropower_countOfSites
# Alabama                     2435
# Alaska                      3053
# Arizona                     1958
#
# [3 rows x 30 columns]

# %%
usretechnical.tail(n=3)
# Out:
#                urbanUtilityScalePV_GWh  urbanUtilityScalePV_GW  \
# West Virginia                     3023                       2
# Wisconsin                        54938                      34
# Wyoming                           7232                       3
#
#                urbanUtilityScalePV_km2  ruralUtilityScalePV_GWh  \
# West Virginia                       41                    52693
# Wisconsin                          727                  5042258
# Wyoming                             75                  5727224
#
#                ruralUtilityScalePV_GW  ruralUtilityScalePV_km2  rooftopPV_GWh  \
# West Virginia                      35                      729         4220.0
# Wisconsin                        3205                    66788        13939.0
# Wyoming                          2854                    59463         1550.0
#
#                rooftopPV_GW  CSP_GWh  CSP_GW  ...  biopowerGaseous_GWh  \
# West Virginia             3        0       0  ...                  281
# Wisconsin                12        0       0  ...                 2072
# Wyoming                   1  5406407    1955  ...                   50
#
#                biopowerGaseous_GW  biopowerGaseous_Tonnes-CH4  \
# West Virginia                   0                       59811
# Wisconsin                       0                      441053
# Wyoming                         0                       10670
#
#                geothermalHydrothermal_GWh  geothermalHydrothermal_GW  \
# West Virginia                           0                          0
# Wisconsin                               0                          0
# Wyoming                              1373                          0
#
#                EGSGeothermal_GWh  EGSGeothermal_GW  hydropower_GWh  \
# West Virginia           261376.0              33.0            4408
# Wisconsin               647173.0              82.0            2286
# Wyoming                1070078.0             135.0            4445
#
#                hydropower_GW  hydropower_countOfSites
# West Virginia              1                     1711
# Wisconsin                  1                     1863
# Wyoming                    1                     2842
#
# [3 rows x 30 columns]

# %%
usretechnical.values  # Values are in a Numpy array
# Out:
# array([[3.58500e+04, 2.00000e+01, 4.26000e+02, ..., 4.10200e+03,
#         0.00000e+00, 2.43500e+03],
#        [1.66000e+02, 0.00000e+00, 2.00000e+00, ..., 2.36750e+04,
#         5.00000e+00, 3.05300e+03],
#        [1.21305e+05, 5.20000e+01, 1.09600e+03, ..., 1.30300e+03,
#         0.00000e+00, 1.95800e+03],
#        ...,
#        [3.02300e+03, 2.00000e+00, 4.10000e+01, ..., 4.40800e+03,
#         1.00000e+00, 1.71100e+03],
#        [5.49380e+04, 3.40000e+01, 7.27000e+02, ..., 2.28600e+03,
#         1.00000e+00, 1.86300e+03],
#        [7.23200e+03, 3.00000e+00, 7.50000e+01, ..., 4.44500e+03,
#         1.00000e+00, 2.84200e+03]])

# %% [markdown]
# The methods `info` and `describe` give respectively general and quantitative information concerning the dataframe.
# In particular, `info` indicates the categorical variables (which are not treated by `describe`).

# %%
usretechnical.describe()
# Out:
#        urbanUtilityScalePV_GWh  urbanUtilityScalePV_GW  \
# count                51.000000               51.000000
# mean              43758.235294               23.431373
# std               54365.369016               27.735360
# min                   8.000000                0.000000
# 25%               12162.000000                6.000000
# 50%               30492.000000               16.000000
# 75%               51824.000000               31.000000
# max              294684.000000              154.000000
#
#        urbanUtilityScalePV_km2  ruralUtilityScalePV_GWh  \
# count                51.000000             5.100000e+01
# mean                496.921569             5.502219e+06
# std                 577.748348             6.284523e+06
# min                   0.000000             0.000000e+00
# 25%                 134.000000             1.296446e+06
# 50%                 338.000000             4.876185e+06
# 75%                 659.500000             8.235158e+06
# max                3213.000000             3.899358e+07
#
#        ruralUtilityScalePV_GW  ruralUtilityScalePV_km2  rooftopPV_GWh  \
# count               51.000000                51.000000      49.000000
# mean              2999.019608             62488.843137   16708.387755
# std               3313.295462             69026.482269   19629.574820
# min                  0.000000                 0.000000    1115.000000
# 25%                792.000000             16508.000000    5336.000000
# 50%               2395.000000             49908.000000   12442.000000
# 75%               4211.000000             87743.000000   19685.000000
# max              20411.000000            425230.000000  106411.000000
#
#        rooftopPV_GW       CSP_GWh       CSP_GW  ...  biopowerGaseous_GWh  \
# count     51.000000  5.100000e+01    51.000000  ...            51.000000
# mean      12.529412  2.277377e+06   746.215686  ...          1735.843137
# std       14.584036  4.716721e+06  1520.849201  ...          2476.107537
# min        1.000000  0.000000e+00     0.000000  ...             4.000000
# 25%        3.000000  0.000000e+00     0.000000  ...           369.000000
# 50%       10.000000  0.000000e+00     0.000000  ...          1063.000000
# 75%       14.000000  2.220892e+06   803.000000  ...          2183.500000
# max       75.000000  2.278675e+07  7743.000000  ...         15510.000000
#
#        biopowerGaseous_GW  biopowerGaseous_Tonnes-CH4  \
# count           51.000000                5.100000e+01
# mean             0.019608                3.694256e+05
# std              0.140028                5.268432e+05
# min              0.000000                9.770000e+02
# 25%              0.000000                7.862050e+04
# 50%              0.000000                2.261780e+05
# 75%              0.000000                4.647680e+05
# max              1.000000                3.300211e+06
#
#        geothermalHydrothermal_GWh  geothermalHydrothermal_GW  \
# count                   51.000000                  51.000000
# mean                  5909.333333                   0.627451
# std                  19616.831126                   2.357633
# min                      0.000000                   0.000000
# 25%                      0.000000                   0.000000
# 50%                      0.000000                   0.000000
# 75%                    686.500000                   0.000000
# max                 130921.000000                  16.000000
#
#        EGSGeothermal_GWh  EGSGeothermal_GW  hydropower_GWh  hydropower_GW  \
# count       4.900000e+01         49.000000       51.000000      51.000000
# mean        6.396872e+05         80.571429     5077.039216       0.745098
# std         5.403773e+05         68.520374     6834.337527       1.547167
# min         6.970000e+02          0.000000        0.000000       0.000000
# 25%         3.532060e+05         44.000000     1278.500000       0.000000
# 50%         4.959210e+05         62.000000     2818.000000       0.000000
# 75%         9.219720e+05        116.000000     4663.500000       1.000000
# max         3.030250e+06        384.000000    30023.000000       6.000000
#
#        hydropower_countOfSites
# count                51.000000
# mean               2512.274510
# std                2182.471948
# min                   2.000000
# 25%                1038.000000
# 50%                1863.000000
# 75%                3127.000000
# max                9692.000000
#
# [8 rows x 30 columns]

# %%
usretechnical.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51 entries, Alabama to Wyoming
# Data columns (total 30 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   urbanUtilityScalePV_GWh     51 non-null     int64
#  1   urbanUtilityScalePV_GW      51 non-null     int64
#  2   urbanUtilityScalePV_km2     51 non-null     int64
#  3   ruralUtilityScalePV_GWh     51 non-null     int64
#  4   ruralUtilityScalePV_GW      51 non-null     int64
#  5   ruralUtilityScalePV_km2     51 non-null     int64
#  6   rooftopPV_GWh               49 non-null     float64
#  7   rooftopPV_GW                51 non-null     int64
#  8   CSP_GWh                     51 non-null     int64
#  9   CSP_GW                      51 non-null     int64
#  10  CSP_km2                     51 non-null     int64
#  11  onshoreWind_GWh             51 non-null     int64
#  12  onshoreWind_GW              51 non-null     int64
#  13  onshoreWind_km2             51 non-null     int64
#  14  offshoreWind_GWh            29 non-null     float64
#  15  offshoreWind_GW             29 non-null     float64
#  16  offshoreWind_km2            29 non-null     float64
#  17  biopowerSolid_GWh           51 non-null     int64
#  18  biopowerSolid_GW            51 non-null     int64
#  19  biopowerSolid_BDT           51 non-null     int64
#  20  biopowerGaseous_GWh         51 non-null     int64
#  21  biopowerGaseous_GW          51 non-null     int64
#  22  biopowerGaseous_Tonnes-CH4  51 non-null     int64
#  23  geothermalHydrothermal_GWh  51 non-null     int64
#  24  geothermalHydrothermal_GW   51 non-null     int64
#  25  EGSGeothermal_GWh           49 non-null     float64
#  26  EGSGeothermal_GW            49 non-null     float64
#  27  hydropower_GWh              51 non-null     int64
#  28  hydropower_GW               51 non-null     int64
#  29  hydropower_countOfSites     51 non-null     int64
# dtypes: float64(6), int64(24)
# memory usage: 12.4+ KB

# %% [markdown]
# In the dataframe, the `biopowerGaseous_GW` variable should be a categorical variable.

# %%
usretechnical['biopowerGaseous_GW']
# Out:
# Alabama                 0
# Alaska                  0
# Arizona                 0
# Arkansas                0
# California              1
# Colorado                0
# Connecticut             0
# Delaware                0
# District of Columbia    0
# Florida                 0
# Georgia                 0
# Hawaii                  0
# Idaho                   0
# Illinois                0
# Indiana                 0
# Iowa                    0
# Kansas                  0
# Kentucky                0
# Louisiana               0
# Maine                   0
# Maryland                0
# Massachusetts           0
# Michigan                0
# Minnesota               0
# Mississippi             0
# Missouri                0
# Montana                 0
# Nebraska                0
# Nevada                  0
# New Hampshire           0
# New Jersey              0
# New Mexico              0
# New York                0
# North Carolina          0
# North Dakota            0
# Ohio                    0
# Oklahoma                0
# Oregon                  0
# Pennsylvania            0
# Rhode Island            0
# South Carolina          0
# South Dakota            0
# Tennessee               0
# Texas                   0
# Utah                    0
# Vermont                 0
# Virginia                0
# Washington              0
# West Virginia           0
# Wisconsin               0
# Wyoming                 0
# Name: biopowerGaseous_GW, dtype: int64

# %%
usretechnical['biopowerGaseous_GW'] = usretechnical['biopowerGaseous_GW'].astype('category')

# %%
usretechnical.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51 entries, Alabama to Wyoming
# Data columns (total 30 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   urbanUtilityScalePV_GWh     51 non-null     int64
#  1   urbanUtilityScalePV_GW      51 non-null     int64
#  2   urbanUtilityScalePV_km2     51 non-null     int64
#  3   ruralUtilityScalePV_GWh     51 non-null     int64
#  4   ruralUtilityScalePV_GW      51 non-null     int64
#  5   ruralUtilityScalePV_km2     51 non-null     int64
#  6   rooftopPV_GWh               49 non-null     float64
#  7   rooftopPV_GW                51 non-null     int64
#  8   CSP_GWh                     51 non-null     int64
#  9   CSP_GW                      51 non-null     int64
#  10  CSP_km2                     51 non-null     int64
#  11  onshoreWind_GWh             51 non-null     int64
#  12  onshoreWind_GW              51 non-null     int64
#  13  onshoreWind_km2             51 non-null     int64
#  14  offshoreWind_GWh            29 non-null     float64
#  15  offshoreWind_GW             29 non-null     float64
#  16  offshoreWind_km2            29 non-null     float64
#  17  biopowerSolid_GWh           51 non-null     int64
#  18  biopowerSolid_GW            51 non-null     int64
#  19  biopowerSolid_BDT           51 non-null     int64
#  20  biopowerGaseous_GWh         51 non-null     int64
#  21  biopowerGaseous_GW          51 non-null     category
#  22  biopowerGaseous_Tonnes-CH4  51 non-null     int64
#  23  geothermalHydrothermal_GWh  51 non-null     int64
#  24  geothermalHydrothermal_GW   51 non-null     int64
#  25  EGSGeothermal_GWh           49 non-null     float64
#  26  EGSGeothermal_GW            49 non-null     float64
#  27  hydropower_GWh              51 non-null     int64
#  28  hydropower_GW               51 non-null     int64
#  29  hydropower_countOfSites     51 non-null     int64
# dtypes: category(1), float64(6), int64(23)
# memory usage: 14.2+ KB

# %% [markdown]
# ## Indexing a table <a id="part1sec2"></a>

# %% [markdown]
# #### Natural indexing

# %% [markdown]
# Explanations are provided with the `usretechnical` dataframe.

# %%
usretechnical['urbanUtilityScalePV_GWh']
# Out:
# Alabama                  35850
# Alaska                     166
# Arizona                 121305
# Arkansas                 28960
# California              246008
# Colorado                 43470
# Connecticut               7716
# Delaware                 14856
# District of Columbia         8
# Florida                  72787
# Georgia                  43166
# Hawaii                    3725
# Idaho                    23194
# Illinois                103551
# Indiana                  98815
# Iowa                     27091
# Kansas                   31705
# Kentucky                 26514
# Louisiana                55669
# Maine                     3216
# Maryland                 28551
# Massachusetts            17469
# Michigan                 50845
# Minnesota                33370
# Mississippi              26366
# Missouri                 30549
# Montana                  11370
# Nebraska                 12954
# Nevada                   24893
# New Hampshire             3790
# New Jersey               44307
# New Mexico               71356
# New York                 52803
# North Carolina           68346
# North Dakota              4871
# Ohio                     86495
# Oklahoma                 50040
# Oregon                   25783
# Pennsylvania             56161
# Rhode Island              1787
# South Carolina           33834
# South Dakota              4573
# Tennessee                50243
# Texas                   294684
# Utah                     30492
# Vermont                   1632
# Virginia                 27451
# Washington               33690
# West Virginia             3023
# Wisconsin                54938
# Wyoming                   7232
# Name: urbanUtilityScalePV_GWh, dtype: int64

# %% [markdown]
# This object is a serie. It can be equivalently obtained using `MyDataFram.MyVariable` :

# %%
s = usretechnical.urbanUtilityScalePV_GWh # a Serie
s['Nevada']
# Out:
# 24893

# %% [markdown]
# You may want to extract several columns or several rows.

# %%
usretechnical[['urbanUtilityScalePV_GWh','offshoreWind_GWh']].head()
# Out:
#             urbanUtilityScalePV_GWh  offshoreWind_GWh
# Alabama                       35850               0.0
# Alaska                          166               NaN
# Arizona                      121305               NaN
# Arkansas                      28960               NaN
# California                   246008         2662579.0

# %%
s[['Nevada', 'Wisconsin']]
# Out:
# Nevada       24893
# Wisconsin    54938
# Name: urbanUtilityScalePV_GWh, dtype: int64

# %% [markdown]
# **Remark:** selecting with `[[]]` always return a dataframe.

# %%
usretechnical[['urbanUtilityScalePV_GWh']].head()
# Out:
#             urbanUtilityScalePV_GWh
# Alabama                       35850
# Alaska                          166
# Arizona                      121305
# Arkansas                      28960
# California                   246008

# %% [markdown]
# #### Label based indexing

# %% [markdown]
# Label based indexing is an enhancement of natural indexing, accessible with `.loc[]`.
#
# Indexing has to be thought *as a matrix but with labels instead of positions*.
#
# Hence, the **rows** are indexed first (instead of the columns with `[]`).

# %%
usretechnical.loc['Nevada']  # Single row
# Out:
# urbanUtilityScalePV_GWh         24893.0
# urbanUtilityScalePV_GW             10.0
# urbanUtilityScalePV_km2           224.0
# ruralUtilityScalePV_GWh       8614454.0
# ruralUtilityScalePV_GW           3732.0
# ruralUtilityScalePV_km2         77751.0
# rooftopPV_GWh                   10767.0
# rooftopPV_GW                        7.0
# CSP_GWh                       8295752.0
# CSP_GW                           2557.0
# CSP_km2                         77759.0
# onshoreWind_GWh                 17709.0
# onshoreWind_GW                      7.0
# onshoreWind_km2                  1449.0
# offshoreWind_GWh                    NaN
# offshoreWind_GW                     NaN
# offshoreWind_km2                    NaN
# biopowerSolid_GWh                 288.0
# biopowerSolid_GW                    0.0
# biopowerSolid_BDT              262613.0
# biopowerGaseous_GWh               325.0
# biopowerGaseous_GW                  0.0
# biopowerGaseous_Tonnes-CH4      69248.0
# geothermalHydrothermal_GWh      45320.0
# geothermalHydrothermal_GW           5.0
# EGSGeothermal_GWh             1262174.0
# EGSGeothermal_GW                  160.0
# hydropower_GWh                    845.0
# hydropower_GW                       0.0
# hydropower_countOfSites          1489.0
# Name: Nevada, dtype: float64

# %%
usretechnical.loc[:, 'urbanUtilityScalePV_GWh'].head()  # Single column
# Out:
# Alabama        35850
# Alaska           166
# Arizona       121305
# Arkansas       28960
# California    246008
# Name: urbanUtilityScalePV_GWh, dtype: int64

# %%
usretechnical.loc[['Nevada', 'Wisconsin']]  # Multiple rows
# Out:
#            urbanUtilityScalePV_GWh  urbanUtilityScalePV_GW  \
# Nevada                       24893                      10
# Wisconsin                    54938                      34
#
#            urbanUtilityScalePV_km2  ruralUtilityScalePV_GWh  \
# Nevada                         224                  8614454
# Wisconsin                      727                  5042258
#
#            ruralUtilityScalePV_GW  ruralUtilityScalePV_km2  rooftopPV_GWh  \
# Nevada                       3732                    77751        10767.0
# Wisconsin                    3205                    66788        13939.0
#
#            rooftopPV_GW  CSP_GWh  CSP_GW  ...  biopowerGaseous_GWh  \
# Nevada                7  8295752    2557  ...                  325
# Wisconsin            12        0       0  ...                 2072
#
#            biopowerGaseous_GW  biopowerGaseous_Tonnes-CH4  \
# Nevada                      0                       69248
# Wisconsin                   0                      441053
#
#            geothermalHydrothermal_GWh  geothermalHydrothermal_GW  \
# Nevada                          45320                          5
# Wisconsin                           0                          0
#
#            EGSGeothermal_GWh  EGSGeothermal_GW  hydropower_GWh  hydropower_GW  \
# Nevada             1262174.0             160.0             845              0
# Wisconsin           647173.0              82.0            2286              1
#
#            hydropower_countOfSites
# Nevada                        1489
# Wisconsin                     1863
#
# [2 rows x 30 columns]

# %% [markdown]
# Slicing on rows and columns is possible but **endpoints are included**.

# %%
usretechnical.loc['Nevada':'New York']  # Row slicing
# Out:
#                urbanUtilityScalePV_GWh  urbanUtilityScalePV_GW  \
# Nevada                           24893                      10
# New Hampshire                     3790                       2
# New Jersey                       44307                      25
# New Mexico                       71356                      30
# New York                         52803                      32
#
#                urbanUtilityScalePV_km2  ruralUtilityScalePV_GWh  \
# Nevada                             224                  8614454
# New Hampshire                       48                    57363
# New Jersey                         527                   439773
# New Mexico                         645                 16318543
# New York                           682                  1492566
#
#                ruralUtilityScalePV_GW  ruralUtilityScalePV_km2  rooftopPV_GWh  \
# Nevada                           3732                    77751        10767.0
# New Hampshire                      35                      741         2298.0
# New Jersey                        251                     5231        15767.0
# New Mexico                       7087                   147652         6513.0
# New York                          926                    19294        28779.0
#
#                rooftopPV_GW   CSP_GWh  CSP_GW  ...  biopowerGaseous_GWh  \
# Nevada                    7   8295752    2557  ...                  325
# New Hampshire             2         0       0  ...                  389
# New Jersey               13         0       0  ...                 2310
# New Mexico                4  16812349    4860  ...                  353
# New York                 25         0       0  ...                 2950
#
#                biopowerGaseous_GW  biopowerGaseous_Tonnes-CH4  \
# Nevada                          0                       69248
# New Hampshire                   0                       82889
# New Jersey                      0                      491691
# New Mexico                      0                       75228
# New York                        0                      627734
#
#                geothermalHydrothermal_GWh  geothermalHydrothermal_GW  \
# Nevada                              45320                          5
# New Hampshire                           0                          0
# New Jersey                              0                          0
# New Mexico                          12933                          1
# New York                                0                          0
#
#                EGSGeothermal_GWh  EGSGeothermal_GW  hydropower_GWh  \
# Nevada                 1262174.0             160.0             845
# New Hampshire           104314.0              13.0            1740
# New Jersey               35230.0               4.0             549
# New Mexico             1417978.0             179.0            1362
# New York                375400.0              47.0            6711
#
#                hydropower_GW  hydropower_countOfSites
# Nevada                     0                     1489
# New Hampshire              0                      810
# New Jersey                 0                      402
# New Mexico                 0                     1810
# New York                   1                     4839
#
# [5 rows x 30 columns]

# %% [markdown]
# #### Integer position based indexing

# %% [markdown]
# Interger location (or position) based indexing is done with `.iloc[]`.
# It is similar to `.loc[]` but considers only integer positions instead of labels.
#
# **Remark:** endpoints are not included (similarly to Numpy).

# %%
usretechnical.iloc[:2]
# Out:
#          urbanUtilityScalePV_GWh  urbanUtilityScalePV_GW  \
# Alabama                    35850                      20
# Alaska                       166                       0
#
#          urbanUtilityScalePV_km2  ruralUtilityScalePV_GWh  \
# Alabama                      426                  3706838
# Alaska                         2                  8282976
#
#          ruralUtilityScalePV_GW  ruralUtilityScalePV_km2  rooftopPV_GWh  \
# Alabama                    2114                    44058        15475.0
# Alaska                     9005                   187608            NaN
#
#          rooftopPV_GW  CSP_GWh  CSP_GW  ...  biopowerGaseous_GWh  \
# Alabama            12        0       0  ...                 1533
# Alaska              1        0       0  ...                   61
#
#          biopowerGaseous_GW  biopowerGaseous_Tonnes-CH4  \
# Alabama                   0                      326186
# Alaska                    0                       13156
#
#          geothermalHydrothermal_GWh  geothermalHydrothermal_GW  \
# Alabama                           0                          0
# Alaska                        15437                          1
#
#          EGSGeothermal_GWh  EGSGeothermal_GW  hydropower_GWh  hydropower_GW  \
# Alabama           535489.0              67.0            4102              0
# Alaska                 NaN               NaN           23675              5
#
#          hydropower_countOfSites
# Alabama                     2435
# Alaska                      3053
#
# [2 rows x 30 columns]

# %%
usretechnical.iloc[10::4, ::2]
# Out:
#               urbanUtilityScalePV_GWh  urbanUtilityScalePV_km2  \
# Georgia                         43166                      505
# Indiana                         98815                     1274
# Louisiana                       55669                      674
# Michigan                        50845                      699
# Montana                         11370                      127
# New Jersey                      44307                      527
# North Dakota                     4871                       57
# Pennsylvania                    56161                      754
# Tennessee                       50243                      595
# Virginia                        27451                      326
# Wyoming                          7232                       75
#
#               ruralUtilityScalePV_GW  rooftopPV_GWh  CSP_GWh  CSP_km2  \
# Georgia                         3088        31116.0        0        0
# Indiana                         3018        17151.0        0        0
# Louisiana                       2394        14368.0        0        0
# Michigan                        3443        23527.0        0        0
# Montana                         4402         2194.0  1540287    16939
# New Jersey                       251        15767.0        0        0
# North Dakota                    5482         1916.0    36049      396
# Pennsylvania                     356        22215.0        0        0
# Tennessee                       1266        19685.0        0        0
# Virginia                        1074        22266.0        0        0
# Wyoming                         2854         1550.0  5406407    59457
#
#               onshoreWind_GW  offshoreWind_GWh  offshoreWind_km2  \
# Georgia                    0          220807.0           11725.0
# Indiana                  148             165.0               9.0
# Louisiana                  0         1200698.0           68122.0
# Michigan                  59         1739800.0           84515.0
# Montana                  944               NaN               NaN
# New Jersey                 0          429807.0           20386.0
# North Dakota             770               NaN               NaN
# Pennsylvania               3           23571.0            1134.0
# Tennessee                  0               NaN               NaN
# Virginia                   1          361053.0           17814.0
# Wyoming                  552               NaN               NaN
#
#               biopowerSolid_GW  biopowerGaseous_GWh  \
# Georgia                      1                 2220
# Indiana                      1                 2978
# Louisiana                    1                  857
# Michigan                     1                 2539
# Montana                      0                  147
# New Jersey                   0                 2310
# North Dakota                 1                   30
# Pennsylvania                 0                 7132
# Tennessee                    0                 1984
# Virginia                     0                 2498
# Wyoming                      0                   50
#
#               biopowerGaseous_Tonnes-CH4  geothermalHydrothermal_GW  \
# Georgia                           472546                          0
# Indiana                           633660                          0
# Louisiana                         182404                          0
# Michigan                          540282                          0
# Montana                            31324                          0
# New Jersey                        491691                          0
# North Dakota                        6383                          0
# Pennsylvania                     1517540                          0
# Tennessee                         422220                          0
# Virginia                          531592                          0
# Wyoming                            10670                          0
#
#               EGSGeothermal_GW  hydropower_GW
# Georgia                   44.0              0
# Indiana                   55.0              0
# Louisiana                 61.0              0
# Michigan                  58.0              0
# Montana                  208.0              3
# New Jersey                 4.0              0
# North Dakota             104.0              0
# Pennsylvania              41.0              1
# Tennessee                 54.0              1
# Virginia                  36.0              0
# Wyoming                  135.0              1

# %% [markdown]
# #### Boolean indexing

# %% [markdown]
# Similarly to Numpy arrays, dataframes can be indexed with Boolean variables thanks to `.loc[]`.

# %%
usretechnical.loc[usretechnical['urbanUtilityScalePV_GWh'] > 50000]  # Row selection
# Out:
#                 urbanUtilityScalePV_GWh  urbanUtilityScalePV_GW  \
# Arizona                          121305                      52
# California                       246008                     111
# Florida                           72787                      39
# Illinois                         103551                      63
# Indiana                           98815                      61
# Louisiana                         55669                      32
# Michigan                          50845                      33
# New Mexico                        71356                      30
# New York                          52803                      32
# North Carolina                    68346                      37
# Ohio                              86495                      57
# Oklahoma                          50040                      25
# Pennsylvania                      56161                      36
# Tennessee                         50243                      28
# Texas                            294684                     154
# Wisconsin                         54938                      34
#
#                 urbanUtilityScalePV_km2  ruralUtilityScalePV_GWh  \
# Arizona                            1096                 11867693
# California                         2320                  8855917
# Florida                             830                  5137346
# Illinois                           1324                  8090985
# Indiana                            1274                  4876185
# Louisiana                           674                  4114605
# Michigan                            699                  5215639
# New Mexico                          645                 16318543
# New York                            682                  1492566
# North Carolina                      789                  4232789
# Ohio                               1190                  3626181
# Oklahoma                            533                  9341920
# Pennsylvania                        754                   553356
# Tennessee                           595                  2225989
# Texas                              3213                 38993581
# Wisconsin                           727                  5042258
#
#                 ruralUtilityScalePV_GW  ruralUtilityScalePV_km2  \
# Arizona                           5147                   107230
# California                        4010                    83549
# Florida                           2812                    58596
# Illinois                          4969                   103524
# Indiana                           3018                    62890
# Louisiana                         2394                    49876
# Michigan                          3443                    71740
# New Mexico                        7087                   147652
# New York                           926                    19294
# North Carolina                    2346                    48892
# Ohio                              2395                    49908
# Oklahoma                          4782                    99640
# Pennsylvania                       356                     7429
# Tennessee                         1266                    26395
# Texas                            20411                   425230
# Wisconsin                         3205                    66788
#
#                 rooftopPV_GWh  rooftopPV_GW   CSP_GWh  CSP_GW  ...  \
# Arizona               22736.0            14  12544333    3527  ...
# California           106411.0            75   8490916    2725  ...
# Florida               63986.0            49       358       0  ...
# Illinois              30086.0            26         0       0  ...
# Indiana               17151.0            14         0       0  ...
# Louisiana             14368.0            11         0       0  ...
# Michigan              23527.0            21         0       0  ...
# New Mexico             6513.0             4  16812349    4860  ...
# New York              28779.0            25         0       0  ...
# North Carolina        28419.0            23         0       0  ...
# Ohio                  30064.0            27         0       0  ...
# Oklahoma              12442.0             9   5068036    1812  ...
# Pennsylvania          22215.0            19         0       0  ...
# Tennessee             19685.0            16         0       0  ...
# Texas                 78716.0            60  22786749    7743  ...
# Wisconsin             13939.0            12         0       0  ...
#
#                 biopowerGaseous_GWh  biopowerGaseous_GW  \
# Arizona                         837                   0
# California                    15510                   1
# Florida                        3693                   0
# Illinois                       4222                   0
# Indiana                        2978                   0
# Louisiana                       857                   0
# Michigan                       2539                   0
# New Mexico                      353                   0
# New York                       2950                   0
# North Carolina                 3780                   0
# Ohio                           3363                   0
# Oklahoma                        965                   0
# Pennsylvania                   7132                   0
# Tennessee                      1984                   0
# Texas                          5898                   0
# Wisconsin                      2072                   0
#
#                 biopowerGaseous_Tonnes-CH4  geothermalHydrothermal_GWh  \
# Arizona                             178188                        8329
# California                         3300211                      130921
# Florida                             785787                           0
# Illinois                            898345                           0
# Indiana                             633660                           0
# Louisiana                           182404                           0
# Michigan                            540282                           0
# New Mexico                           75228                       12933
# New York                            627734                           0
# North Carolina                      804301                           0
# Ohio                                715603                           0
# Oklahoma                            205359                           0
# Pennsylvania                       1517540                           0
# Tennessee                           422220                           0
# Texas                              1254999                           0
# Wisconsin                           441053                           0
#
#                 geothermalHydrothermal_GW  EGSGeothermal_GWh  \
# Arizona                                 1          1239147.0
# California                             16          1344179.0
# Florida                                 0           374161.0
# Illinois                                0           676055.0
# Indiana                                 0           434258.0
# Louisiana                               0           484271.0
# Michigan                                0           457850.0
# New Mexico                              1          1417978.0
# New York                                0           375400.0
# North Carolina                          0           420741.0
# Ohio                                    0           495921.0
# Oklahoma                                0           779667.0
# Pennsylvania                            0           327340.0
# Tennessee                               0           428380.0
# Texas                                   0          3030250.0
# Wisconsin                               0           647173.0
#
#                 EGSGeothermal_GW  hydropower_GWh  hydropower_GW  \
# Arizona                    157.0            1303              0
# California                 170.0           30023              6
# Florida                     47.0             682              0
# Illinois                    85.0            4882              1
# Indiana                     55.0            2394              0
# Louisiana                   61.0            2423              0
# Michigan                    58.0            1180              0
# New Mexico                 179.0            1362              0
# New York                    47.0            6711              1
# North Carolina              53.0            3036              0
# Ohio                        62.0            3045              0
# Oklahoma                    98.0            3015              0
# Pennsylvania                41.0            8368              1
# Tennessee                   54.0            5744              1
# Texas                      384.0            3006              0
# Wisconsin                   82.0            2286              1
#
#                 hydropower_countOfSites
# Arizona                            1958
# California                         9692
# Florida                             493
# Illinois                           1330
# Indiana                            1142
# Louisiana                           934
# Michigan                           1942
# New Mexico                         1810
# New York                           4839
# North Carolina                     2131
# Ohio                               1791
# Oklahoma                           2824
# Pennsylvania                       4466
# Tennessee                          2610
# Texas                              4366
# Wisconsin                          1863
#
# [16 rows x 30 columns]

# %% [markdown]
# #### Selection random samples
#
# The `sample` method makes it possible to randomly select rows (individuals) from a dataframe (without replacement).

# %%
usretechnical.sample(n=3)
# Out:
#             urbanUtilityScalePV_GWh  urbanUtilityScalePV_GW  \
# Washington                    33690                      19
# Nebraska                      12954                       6
# Arkansas                      28960                      15
#
#             urbanUtilityScalePV_km2  ruralUtilityScalePV_GWh  \
# Washington                      402                  1738150
# Nebraska                        141                  9266756
# Arkansas                        332                  4986388
#
#             ruralUtilityScalePV_GW  ruralUtilityScalePV_km2  rooftopPV_GWh  \
# Washington                     996                    20758        13599.0
# Nebraska                      4869                   101456         5336.0
# Arkansas                      2747                    57239         8484.0
#
#             rooftopPV_GW  CSP_GWh  CSP_GW  ...  biopowerGaseous_GWh  \
# Washington            13   161713      58  ...                 1514
# Nebraska               4  4846929    1753  ...                  750
# Arkansas               6        0       0  ...                 1063
#
#             biopowerGaseous_GW  biopowerGaseous_Tonnes-CH4  \
# Washington                   0                      322155
# Nebraska                     0                      159729
# Arkansas                     0                      226178
#
#             geothermalHydrothermal_GWh  geothermalHydrothermal_GW  \
# Washington                        2546                          0
# Nebraska                             0                          0
# Arkansas                             0                          0
#
#             EGSGeothermal_GWh  EGSGeothermal_GW  hydropower_GWh  \
# Washington           563023.0              71.0           27248
# Nebraska             927996.0             117.0            3142
# Arkansas             628621.0              79.0            6093
#
#             hydropower_GW  hydropower_countOfSites
# Washington              6                     7310
# Nebraska                0                     2880
# Arkansas                1                     3268
#
# [3 rows x 30 columns]

# %% [markdown]
# ## Adding and deleting items <a id="part2sec4"></a>

# %% [markdown]
# Let us consider a copy of the first 5 rows of `consumption`.

# %%
usbis= usretechnical.iloc[:5,[1,4]].copy()
usbis
# Out:
#             urbanUtilityScalePV_GW  ruralUtilityScalePV_GW
# Alabama                         20                    2114
# Alaska                           0                    9005
# Arizona                         52                    5147
# Arkansas                        15                    2747
# California                     111                    4010

# %% [markdown]
# We successively add a column and a row to `usbis`.

# %%
usbis['sum'] = usbis.sum(axis=1)
usbis.loc['PaysDeLaLoire'] = [10000, 100, 10100]
usbis
# Out:
#                urbanUtilityScalePV_GW  ruralUtilityScalePV_GW    sum
# Alabama                            20                    2114   2134
# Alaska                              0                    9005   9005
# Arizona                            52                    5147   5199
# Arkansas                           15                    2747   2762
# California                        111                    4010   4121
# PaysDeLaLoire                   10000                     100  10100

# %% [markdown]
# that we can now drop

# %%
usbis = usbis.drop('PaysDeLaLoire')
usbis = usbis.drop('sum', axis=1)
usbis
# Out:
#             urbanUtilityScalePV_GW  ruralUtilityScalePV_GW
# Alabama                         20                    2114
# Alaska                           0                    9005
# Arizona                         52                    5147
# Arkansas                        15                    2747
# California                     111                    4010

# %% [markdown]
# ## Managing missing data <a id="part2sec5"></a>

# %% [markdown]
# Missing data are generally replaced by a `NaN` in the table.
# Pandas offers several possibilities to manage them.

# %%
#offshorewind_gwh
#offshorewind_gw
uster= usretechnical.iloc[:15,6:8].copy()
uster.head()  # A table with missing data
# Out:
#             rooftopPV_GWh  rooftopPV_GW
# Alabama           15475.0            12
# Alaska                NaN             1
# Arizona           22736.0            14
# Arkansas           8484.0             6
# California       106411.0            75

# %%
uster.dropna()  # Drop any row with missing data
# Out:
#                       rooftopPV_GWh  rooftopPV_GW
# Alabama                     15475.0            12
# Arizona                     22736.0            14
# Arkansas                     8484.0             6
# California                 106411.0            75
# Colorado                    16162.0            11
# Connecticut                  6616.0             5
# Delaware                     2185.0             1
# District of Columbia         2490.0             2
# Florida                     63986.0            49
# Georgia                     31116.0            24
# Idaho                        4051.0             3
# Illinois                    30086.0            26
# Indiana                     17151.0            14

# %%
uster.isnull().any()  # Test for missing data
# Out:
# rooftopPV_GWh     True
# rooftopPV_GW     False
# dtype: bool

# %% [markdown]
# > **Question**
# >
# > By changing the `axis` parameter of `dropna`, drop the columns with missing values of `usretechnical`.

# %%
# Answer
uster.dropna(axis = 1)
# Out:
#                       rooftopPV_GW
# Alabama                         12
# Alaska                           1
# Arizona                         14
# Arkansas                         6
# California                      75
# Colorado                        11
# Connecticut                      5
# Delaware                         1
# District of Columbia             2
# Florida                         49
# Georgia                         24
# Hawaii                           2
# Idaho                            3
# Illinois                        26
# Indiana                         14

# %% [markdown]
# ## Analyzing and Visualizing a Quantitative Variable

# %% [markdown]
# #### Descriptive statistics <a id="part1sec6"></a>
#
#
# A dataframe comes with many methods for descriptive statistics:
# - `count`: 	Number of non-null observations;
# - `sum`: 	Sum of values;
# - `mean`: 	Mean of values;
# - `mad`: 	Mean absolute deviation;
# - `median`: 	Arithmetic median of values;
# - `min`: 	Minimum;
# - `max`: 	Maximum;
# - `mode`: 	Mode;
# - `abs`: 	Absolute Value;
# - `prod`: 	Product of values;
# - `std`: 	Bessel-corrected sample standard deviation;
# - `var`: 	Unbiased variance;
# - `sem`: 	Standard error of the mean;
# - `skew`: 	Sample skewness (3rd moment);
# - `kurt`: 	Sample kurtosis (4th moment);
# - `quantile`: 	Sample quantile (value at %);
# - `cumsum`: 	Cumulative sum;
# - `cumprod`: 	Cumulative product;
# - `cummax`: 	Cumulative maximum;
# - `cummin`: 	Cumulative minimum.

# %%
usretechnical.dtypes
# Out:
# urbanUtilityScalePV_GWh          int64
# urbanUtilityScalePV_GW           int64
# urbanUtilityScalePV_km2          int64
# ruralUtilityScalePV_GWh          int64
# ruralUtilityScalePV_GW           int64
# ruralUtilityScalePV_km2          int64
# rooftopPV_GWh                  float64
# rooftopPV_GW                     int64
# CSP_GWh                          int64
# CSP_GW                           int64
# CSP_km2                          int64
# onshoreWind_GWh                  int64
# onshoreWind_GW                   int64
# onshoreWind_km2                  int64
# offshoreWind_GWh               float64
# offshoreWind_GW                float64
# offshoreWind_km2               float64
# biopowerSolid_GWh                int64
# biopowerSolid_GW                 int64
# biopowerSolid_BDT                int64
# biopowerGaseous_GWh              int64
# biopowerGaseous_GW            category
# biopowerGaseous_Tonnes-CH4       int64
# geothermalHydrothermal_GWh       int64
# geothermalHydrothermal_GW        int64
# EGSGeothermal_GWh              float64
# EGSGeothermal_GW               float64
# hydropower_GWh                   int64
# hydropower_GW                    int64
# hydropower_countOfSites          int64
# dtype: object

# %%
usretechnical.median(numeric_only = True)  # Median of numeric columns
# Out:
# urbanUtilityScalePV_GWh         30492.0
# urbanUtilityScalePV_GW             16.0
# urbanUtilityScalePV_km2           338.0
# ruralUtilityScalePV_GWh       4876185.0
# ruralUtilityScalePV_GW           2395.0
# ruralUtilityScalePV_km2         49908.0
# rooftopPV_GWh                   12442.0
# rooftopPV_GW                       10.0
# CSP_GWh                             0.0
# CSP_GW                              0.0
# CSP_km2                             0.0
# onshoreWind_GWh                 28742.0
# onshoreWind_GW                     11.0
# onshoreWind_km2                  2250.0
# offshoreWind_GWh               317754.0
# offshoreWind_GW                    80.0
# offshoreWind_km2                16134.0
# biopowerSolid_GWh                6984.0
# biopowerSolid_GW                    0.0
# biopowerSolid_BDT             6349820.0
# biopowerGaseous_GWh              1063.0
# biopowerGaseous_Tonnes-CH4     226178.0
# geothermalHydrothermal_GWh          0.0
# geothermalHydrothermal_GW           0.0
# EGSGeothermal_GWh              495921.0
# EGSGeothermal_GW                   62.0
# hydropower_GWh                   2818.0
# hydropower_GW                       0.0
# hydropower_countOfSites          1863.0
# dtype: float64

# %%
usretechnical['urbanUtilityScalePV_GWh'].mean()
# Out:
# 43758.23529411765

# %% [markdown]
# > **Question**
# >
# > Compute the median m of the `urbanUtilityScalePV_GWh` variable. Compute the mean of the `ruralUtilityScalePV_GWh`variable
# > - on the subset of states for which with `urbanUtilityScalePV_GWh` is larger than m
# > - on the subset of the states for which `urbanUtilityScalePV_GWh` is smaller than m

# %%
# Answer 
s = usretechnical['urbanUtilityScalePV_GWh']
m = s.median()
print(m)
print(usretechnical['ruralUtilityScalePV_GWh'].loc[s>m].mean())
print(usretechnical['ruralUtilityScalePV_GWh'].loc[s<m].mean())
# Out:
# 30492.0
# 7399351.36
# 3617781.12

# %% [markdown]
# > **Question**
# >
# > What is the offshore Wind Power of all US ?

# %%
# Answer 
print(usretechnical['offshoreWind_GW'].isna().sum())
print(usretechnical['offshoreWind_GW'].count())
print(usretechnical['offshoreWind_GW'].loc[usretechnical['offshoreWind_GW']>0].count())
print(len(usretechnical['offshoreWind_GW']))
usretechnical['offshoreWind_GW'].sum()
# Out:
# 22
# 29
# 27
# 51
# 4210.0

# %% [markdown]
# > **Question**
# > Check that the quantile 20% of the [CSP variable](https://en.wikipedia.org/wiki/Concentrated_solar_power) is equal to 0. How > do you explain this ?

# %%
# Answer
usretechnical['CSP_GWh'].info()
print(usretechnical['CSP_GWh'].quantile(0.2))
print(usretechnical['CSP_GWh'].loc[usretechnical['CSP_GWh'] == 0].count())
# Out:
# <class 'pandas.core.series.Series'>
# Index: 51 entries, Alabama to Wyoming
# Series name: CSP_GWh
# Non-Null Count  Dtype
# --------------  -----
# 51 non-null     int64
# dtypes: int64(1)
# memory usage: 2.9+ KB
# 0.0
# 32

# %% [markdown]
# #### Histograms
# A common task in statisics is to estimate a distribution from a data sample.
# In a first approach, this task can be achieved by computing a histogram.

# %%
import matplotlib.pyplot as plt

x = usretechnical['urbanUtilityScalePV_GWh']

plt.figure(figsize=(7, 5))
plt.hist(x, bins=20, density=True)
plt.xlabel('urbanUtilityScalePV_GWh')
plt.ylabel('Frequency')
plt.title('Histogram of urbanUtilityScalePV_GWh')
plt.show()

# %% [markdown]
# #### Kernel density estimation
# Kernel density estimation is a tool more efficient than a histogram for density estimation.
# In Python, kernel density estimation can be performed with the `gaussian_kde` function.

# %%
grid = np.linspace(1,300000,10000)

# %%
from scipy.stats import gaussian_kde

kde = gaussian_kde(x)

fig, ax = plt.subplots()
(hist_plt, bins_plt, patches) = ax.hist(x, bins=20, density=True)
ax.plot(grid, kde(grid), color="magenta", linewidth=2, label="kde")
ax.legend();

# %% [markdown]
# Under the assumption that the distribution belongs to a given parametric family, you can estimate the paramter of the distribution with the maximum likelihood method (see next lab).

# %% [markdown]
# #### Boxplots

# %% [markdown]
# You can draw boxplots using:
# - the [boxplot](https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.boxplot.html) function of matplotlib,
# - the [boxplot(column)](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.boxplot.html) method on a pandas DataFrame
# - [.plot.box()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.plot.box.html) on a Series pandas
# - the [boxplot](https://seaborn.pydata.org/generated/seaborn.boxplot.html?highlight=boxplot#seaborn.boxplot) function of seaborn.

# %% [markdown]
# Below is a boxplot for the `urbanUtilityScalePV_GWh` variable using seaborn.

# %%
sns.boxplot(data = usretechnical.urbanUtilityScalePV_GWh )
# Out:
# c:\Users\remi\anaconda3\envs\python3_10_infoia\lib\site-packages\seaborn\categorical.py:486: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if np.isscalar(data[0]):
# <Axes: >

# %% [markdown]
# > **Question**
# >
# > Display on the same graph the boxplots of the `onshoreWind_GW` and the `offshoreWind_GW` variables using the boxplot function of pandas.

# %%
# Answer
#sns.boxplot(data = [usretechnical['onshoreWind_GW'], usretechnical['offshoreWind_GW']])
usretechnical[['onshoreWind_GW', 'offshoreWind_GW']].boxplot()
# Out:
# <Axes: >

# %% [markdown]
# #### Violon plots

# %% [markdown]
# Violin plots are boxplots that also estimate and represent densities. The graphical representation is more advanced but beware of borderline cases, because the density estimate is not always appropriate (sample size too small, the estimate may "exceed" the min/max of the data).
#
# - [violinplot](https://seaborn.pydata.org/generated/seaborn.violinplot.html) function from seaborn
# - [violinplot](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.violinplot.html) function from matplotlib
# - No method on DataFrame

# %% [markdown]
# > **Question**
# >
# > Display on the same graph the violon plots of the `urbanUtilityScalePV_GWh` and `ruralUtilityScalePV_GWh` variables using seaborn

# %%
# Answer
sns.violinplot(data = [usretechnical['urbanUtilityScalePV_GWh'], usretechnical['ruralUtilityScalePV_GWh']])
# Out:
# <Axes: >

# %% [markdown]
# ## Analyzing and Visualizing a Categorical Variable

# %% [markdown]
# We first create a Categorical variable that corresponds to a discretization of the continuous variable
# `urbanUtilityScalePV_GWh`.

# %%
q1 = usretechnical.urbanUtilityScalePV_GWh.quantile(0.33) 
q2 = usretechnical.urbanUtilityScalePV_GWh.quantile(0.66) 

usretechnical['UrbanPV_Class'] = pd.cut(usretechnical['urbanUtilityScalePV_GWh'],
                            bins=[0, q1, q2, float('Inf')],
                            labels=['low', 'middle', 'high'])

usretechnical.head()
# Out:
#             urbanUtilityScalePV_GWh  urbanUtilityScalePV_GW  \
# Alabama                       35850                      20
# Alaska                          166                       0
# Arizona                      121305                      52
# Arkansas                      28960                      15
# California                   246008                     111
#
#             urbanUtilityScalePV_km2  ruralUtilityScalePV_GWh  \
# Alabama                         426                  3706838
# Alaska                            2                  8282976
# Arizona                        1096                 11867693
# Arkansas                        332                  4986388
# California                     2320                  8855917
#
#             ruralUtilityScalePV_GW  ruralUtilityScalePV_km2  rooftopPV_GWh  \
# Alabama                       2114                    44058        15475.0
# Alaska                        9005                   187608            NaN
# Arizona                       5147                   107230        22736.0
# Arkansas                      2747                    57239         8484.0
# California                    4010                    83549       106411.0
#
#             rooftopPV_GW   CSP_GWh  CSP_GW  ...  biopowerGaseous_GW  \
# Alabama               12         0       0  ...                   0
# Alaska                 1         0       0  ...                   0
# Arizona               14  12544333    3527  ...                   0
# Arkansas               6         0       0  ...                   0
# California            75   8490916    2725  ...                   1
#
#             biopowerGaseous_Tonnes-CH4  geothermalHydrothermal_GWh  \
# Alabama                         326186                           0
# Alaska                           13156                       15437
# Arizona                         178188                        8329
# Arkansas                        226178                           0
# California                     3300211                      130921
#
#             geothermalHydrothermal_GW  EGSGeothermal_GWh  EGSGeothermal_GW  \
# Alabama                             0           535489.0              67.0
# Alaska                              1                NaN               NaN
# Arizona                             1          1239147.0             157.0
# Arkansas                            0           628621.0              79.0
# California                         16          1344179.0             170.0
#
#             hydropower_GWh  hydropower_GW  hydropower_countOfSites  \
# Alabama               4102              0                     2435
# Alaska               23675              5                     3053
# Arizona               1303              0                     1958
# Arkansas              6093              1                     3268
# California           30023              6                     9692
#
#             UrbanPV_Class
# Alabama            middle
# Alaska                low
# Arizona              high
# Arkansas           middle
# California           high
#
# [5 rows x 31 columns]

# %% [markdown]
# > **Question**
# >
# > Create in the same way a new variable `RuralPV_Class` corresponding to a discretization of the continuous variable  `ruralUtilityScalePV_GWh`.

# %%
# Answer
q1n = usretechnical.ruralUtilityScalePV_GWh.quantile(0.33) 
q2n = usretechnical.ruralUtilityScalePV_GWh.quantile(0.66) 

usretechnical['RuralPV_Class'] = pd.cut(usretechnical['ruralUtilityScalePV_GWh'],
                            bins=[0, q1n, q2n, float('Inf')],
                            labels=['low', 'middle', 'high'])

usretechnical.head()
# Out:
#             urbanUtilityScalePV_GWh  urbanUtilityScalePV_GW  \
# Alabama                       35850                      20
# Alaska                          166                       0
# Arizona                      121305                      52
# Arkansas                      28960                      15
# California                   246008                     111
#
#             urbanUtilityScalePV_km2  ruralUtilityScalePV_GWh  \
# Alabama                         426                  3706838
# Alaska                            2                  8282976
# Arizona                        1096                 11867693
# Arkansas                        332                  4986388
# California                     2320                  8855917
#
#             ruralUtilityScalePV_GW  ruralUtilityScalePV_km2  rooftopPV_GWh  \
# Alabama                       2114                    44058        15475.0
# Alaska                        9005                   187608            NaN
# Arizona                       5147                   107230        22736.0
# Arkansas                      2747                    57239         8484.0
# California                    4010                    83549       106411.0
#
#             rooftopPV_GW   CSP_GWh  CSP_GW  ...  biopowerGaseous_Tonnes-CH4  \
# Alabama               12         0       0  ...                      326186
# Alaska                 1         0       0  ...                       13156
# Arizona               14  12544333    3527  ...                      178188
# Arkansas               6         0       0  ...                      226178
# California            75   8490916    2725  ...                     3300211
#
#             geothermalHydrothermal_GWh  geothermalHydrothermal_GW  \
# Alabama                              0                          0
# Alaska                           15437                          1
# Arizona                           8329                          1
# Arkansas                             0                          0
# California                      130921                         16
#
#             EGSGeothermal_GWh  EGSGeothermal_GW  hydropower_GWh  \
# Alabama              535489.0              67.0            4102
# Alaska                    NaN               NaN           23675
# Arizona             1239147.0             157.0            1303
# Arkansas             628621.0              79.0            6093
# California          1344179.0             170.0           30023
#
#             hydropower_GW  hydropower_countOfSites  UrbanPV_Class  \
# Alabama                 0                     2435         middle
# Alaska                  5                     3053            low
# Arizona                 0                     1958           high
# Arkansas                1                     3268         middle
# California              6                     9692           high
#
#             RuralPV_Class
# Alabama            middle
# Alaska               high
# Arizona              high
# Arkansas           middle
# California           high
#
# [5 rows x 32 columns]

# %% [markdown]
# > **Question**
# >
# > Create a new variable `SCP0` taking the value 1 if CSP_GW = 0 and 0 otherwise.

# %%
# Answer
usretechnical = usretechnical.assign(SCP0 = 1 if usretechnical.CSP_GW.equals(0) else 0)

# %%
usretechnical.head()
# Out:
#             urbanUtilityScalePV_GWh  urbanUtilityScalePV_GW  \
# Alabama                       35850                      20
# Alaska                          166                       0
# Arizona                      121305                      52
# Arkansas                      28960                      15
# California                   246008                     111
#
#             urbanUtilityScalePV_km2  ruralUtilityScalePV_GWh  \
# Alabama                         426                  3706838
# Alaska                            2                  8282976
# Arizona                        1096                 11867693
# Arkansas                        332                  4986388
# California                     2320                  8855917
#
#             ruralUtilityScalePV_GW  ruralUtilityScalePV_km2  rooftopPV_GWh  \
# Alabama                       2114                    44058        15475.0
# Alaska                        9005                   187608            NaN
# Arizona                       5147                   107230        22736.0
# Arkansas                      2747                    57239         8484.0
# California                    4010                    83549       106411.0
#
#             rooftopPV_GW   CSP_GWh  CSP_GW  ...  geothermalHydrothermal_GWh  \
# Alabama               12         0       0  ...                           0
# Alaska                 1         0       0  ...                       15437
# Arizona               14  12544333    3527  ...                        8329
# Arkansas               6         0       0  ...                           0
# California            75   8490916    2725  ...                      130921
#
#             geothermalHydrothermal_GW  EGSGeothermal_GWh  EGSGeothermal_GW  \
# Alabama                             0           535489.0              67.0
# Alaska                              1                NaN               NaN
# Arizona                             1          1239147.0             157.0
# Arkansas                            0           628621.0              79.0
# California                         16          1344179.0             170.0
#
#             hydropower_GWh  hydropower_GW  hydropower_countOfSites  \
# Alabama               4102              0                     2435
# Alaska               23675              5                     3053
# Arizona               1303              0                     1958
# Arkansas              6093              1                     3268
# California           30023              6                     9692
#
#             UrbanPV_Class  RuralPV_Class  SCP0
# Alabama            middle         middle     0
# Alaska                low           high     0
# Arizona              high           high     0
# Arkansas           middle         middle     0
# California           high           high     0
#
# [5 rows x 33 columns]

# %% [markdown]
# #### Statistiques descriptives

# %% [markdown]
# The `describe` method also display statistics for categorical variables.
#
# In the case a variable has not the `category` type, you can change it using the `astype('category')` method (see [doc](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.astype.html)).

# %%
usretechnical.describe(include='category')
# Out:
#         biopowerGaseous_GW UrbanPV_Class RuralPV_Class
# count                   51            51            50
# unique                   2             3             3
# top                      0           low        middle
# freq                    50            17            17

# %% [markdown]
# > **Question**
# >
# > For each categorical variable, display the values it can take using the function [unique](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.unique.html). Then display the number of observations for each of these categories using [value_counts](https://pandas.pydata.org/docs/reference/api/pandas.Series.value_counts.html). Sort the results in **descending** order with [sort_values](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.sort_values.html).

# %%
# Answer 
df = usretechnical.select_dtypes(include=['category'])
for column in df.columns:
    print(df[column].unique())
# Out:
# [0, 1]
# Categories (2, int64): [0, 1]
# ['middle', 'low', 'high']
# Categories (3, object): ['low' < 'middle' < 'high']
# ['middle', 'high', 'low', NaN]
# Categories (3, object): ['low' < 'middle' < 'high']

# %%
# Answer
# Answer 
df = usretechnical.select_dtypes(include=['category'])
for column in df.columns:
    print(df[column].value_counts().sort_values())
# Out:
# biopowerGaseous_GW
# 1     1
# 0    50
# Name: count, dtype: int64
# UrbanPV_Class
# low       17
# middle    17
# high      17
# Name: count, dtype: int64
# RuralPV_Class
# low       16
# middle    17
# high      17
# Name: count, dtype: int64

# %%
usretechnical['RuralPV_Class'].value_counts().sort_values(ascending=False)
# Out:
# RuralPV_Class
# middle    17
# high      17
# low       16
# Name: count, dtype: int64

# %%
usretechnical['SCP0'].value_counts().sort_values(ascending=False)
# Out:
# SCP0
# 0    51
# Name: count, dtype: int64

# %% [markdown]
# #### Bar plot

# %% [markdown]
# We compute the table of frequencies of the variable `SCP0` with the function [crosstab](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.crosstab.html). Make the sum of the frequencies equal to 1 and store the result in a variable.

# %%
cross = pd.crosstab(usretechnical['SCP0'], "freq", normalize=True)
cross
# Out:
# col_0  freq
# SCP0
# 0       1.0

# %% [markdown]
# Display a barplot of `SCP0` (not to be confused with a histogram!), using the `.plot.bar` method on the frequency table.

# %%
cross.plot.bar()
plt.show()

# %% [markdown]
# ## Bivariate descriptive statistics

# %% [markdown]
# In this section, we study the correlations between pairs of variables. Of course, a non-null correlation does not mean causality (see for example this popular page on this subject).
#
# In the following, we compute correlations and we propose graphical representations to study and illustrate these correlations. Note, however, that to rigorously establish the existence of a correlation, a simple graph is not sufficient. This would require the use of statistical tests (not studied in this course).

# %% [markdown]
# ### Two numerical variables (quantitative - quantitative)

# %% [markdown]
# For convenience, for this lab we first extract a sub Dataframe with only a few variables
#
# We also pay attention to keep only one variable per energy type.
#
# > **Question**
# >
# > Extract a sub dataframe `sub_US_re` containing only the columns:
# > - urbanUtilityScalePV_GWh
# > - ruralUtilityScalePV_GWh
# > - rooftopPV_GWh
# > - CSP_GWh
# > - onshoreWind_GWh
# > - offshoreWind_GWh

# %%
# Answer

# %% [markdown]
# #### Correlation Matrix

# %% [markdown]
# Using the [corr](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.corr.html) method, compute the [correlation matrix](https://en.wikipedia.org/wiki/Correlation#Correlation_matrices)  of the **numeric** data from the dataset `usretechnical`.

# %%
sub_US_re.corr()

# %% [markdown]
# Does it makes sense that `urbanUtilityScalePV_GWh` and `rooftopPV_GWh` are strongly corrolated ?
#
#
# Hypothesis : it can be expected that these two variables are both correlated with the state's level of urbanization.

# %% [markdown]
# > **Question**
# >
# > Display the seaborn heatmap of this correlation matrix using the [heatmap](https://seaborn.pydata.org/generated/seaborn.heatmap.html) function. Choose a colormap using [this link](https://matplotlib.org/stable/tutorials/colors/colormaps.html), and make the scale of values go from 0 to 1.

# %%
# Answer

# %% [markdown]
# #### Scatter points

# %% [markdown]
# Scatter points probide crossed vizualizations of two numerical variables
#
#
# > **Question**
# > Using the [scatter](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html) function from matplotlib, display a scatter plot with `urbanUtilityScalePV_GWh` on the y-axis and and `rooftopPV_GWh` on the x-axis. Add names to the axes and to the figure.

# %%
# Answer

# %% [markdown]
# > **Question**
# >
# > Same question using the  [scatterplot](https://seaborn.pydata.org/generated/seaborn.scatterplot.html) function of Seaborn.

# %%
# Answer

# %% [markdown]
# Seaborn also provides the [jointplot](https://seaborn.pydata.org/generated/seaborn.jointplot.html#seaborn.jointplot) function to combine univariate and bivariate representations.

# %%
sns.jointplot(data = usretechnical,  x='urbanUtilityScalePV_GWh', y='rooftopPV_GWh')

# %% [markdown]
# Pandas also provide the function [scatter_matrix](https://pandas.pydata.org/docs/reference/api/pandas.plotting.scatter_matrix.html) (`plotting` module) to display all pairs of clouds of points with the numeric variables of the dataset.
#
# > **Question**
# >
# > Apply this function the `sub_US_re` Dataframe.
# > Don't forget to change the size of the figure.

# %%
# Answer

# %% [markdown]
# ### A numerical variable and a categorical variable (quantitative - qualitative)

# %% [markdown]
# We study a potential correlation between `ruralUtilityScalePV_GWh` and `SCP0`.

# %%
usretechnical.groupby('SCP0')[['ruralUtilityScalePV_GWh']].describe()

# %% [markdown]
# It seems that ruralUtilityScalePV_GWh tends to be lower when SCP0 = 1.

# %% [markdown]
# #### Violon plots and boxplots

# %% [markdown]
# We can compare the two distributions of `ruralUtilityScalePV_GWh` conditionnaly to SCP0 = 0 or 1, using violon plots and boxplots.

# %%
sns.violinplot(data = usretechnical, x='SCP0', y='ruralUtilityScalePV_GWh')

# %% [markdown]
# The distribution of `ruralUtilityScalePV` is more concentrated when SCP=0 than when SCP=0. Higher values of `ruralUtilityScalePV` are observed when SCP >0, indeed a few extremal points are observed for SCP >0.

# %% [markdown]
# > **Question**
# >
# > Display a similar representation using boxplots

# %%
# Answer

# %% [markdown]
# Box plots clearly provide a more efficient representation for analyzing extreme points (sometimes called "outliers").

# %% [markdown]
# ### Two categorical (qualitative - qualitative)

# %% [markdown]
# #### Contengency table

# %% [markdown]
# The contingency table between two categorical variables is calculated with the pandas [crosstab](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.crosstab.html) function. Compute the contingency table of the `SCP0` and `RuralPV_Class` variables.

# %%
pd.crosstab(usretechnical['SCP0'], usretechnical['RuralPV_Class'])

# %% [markdown]
# The `margins` parameter can be used to also compute subtotals by row and column:

# %%
pd.crosstab(usretechnical['SCP0'], usretechnical['RuralPV_Class'], margins=True)

# %% [markdown]
# You can also use `normalize` to normalize the counts in various ways:

# %%
pd.crosstab(usretechnical['SCP0'], usretechnical['RuralPV_Class'],  normalize=True)

# %%
pd.crosstab(usretechnical['SCP0'], usretechnical['RuralPV_Class'],  normalize='index', margins=True)

# %%
pd.crosstab(usretechnical['SCP0'], usretechnical['RuralPV_Class'],   normalize='columns', margins=True)

# %% [markdown]
# #### Diagramme en barres

# %% [markdown]
# > **Question**
# >
# > Check that the contingency table is a data frame. Use the `plot.bar` method to draw a bar graph for the values of the contingency table of `SCP0` and `RuralPV_Class`. Put
# `SCP0` on the x-axis sex, the number of observations in each group on the y-axis, distinguishing `RuralPV_Class` = low, middle or high, with colors.

# %%
# Answer

# %% [markdown]
# > **Question**
# >
# > You can also change the order of the variables in the contingency table and display the corresponding barplot.

# %%
# Answer
